# %%
import importlib
import src.plots

importlib.reload(src.plots)
# Out:
# <module 'src.plots' from '/Users/milenaangelova/git-repo/FedClust/src/plots.py'>

# %%
from src.plots import plot_plotly, preprocessing_results, preprocessing_results_all_clients2, plot_plotly2, plot_plotly3, plot_plotly_real

# %%
# experiment 1, local epochs 3 local concept drift
# local_FedCluLearn = 'results_FedCluLearn_2025-02-05 11:02:47.756245.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-05 11:02:47.756245.txt'
# local_FedAvg = 'results_FedAvg_2025-02-05 11:02:59.570648.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-05 11:02:59.570648.txt'

# # epsilon = 0.1
# local_FedAtt = 'results_FedAtt_2025-02-15 14:24:24.188745.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-15 14:24:24.188745.txt'
# local_FedProx = 'results_FedProx_2025-02-16 08:55:52.957901.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-16 08:55:52.957901.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-26 12:05:46.452219.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-26 12:05:46.452219.txt'

# # experiment 2, local epochs 3, global concept drift
# local_FedAvg = 'results_FedAvg_2025-02-07 11:41:15.393233.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-07 11:41:15.393233.txt'
# local_FedCluLearn = 'results_FedCluLearn_2025-02-07 11:41:24.215176.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-07 11:41:24.215176.txt'
# local_FedProx = 'results_FedProx_2025-02-16 09:21:22.183043.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-16 09:21:22.183043.txt'
# local_FedAtt = 'results_FedAtt_2025-02-15 15:07:47.939783.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-15 15:07:47.939783.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-25 20:53:12.002487.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-25 20:53:12.002487.txt'

#global schema - a new ones - sequential
# local_FedCluLearn = 'results_FedCluLearn_2025-02-26 12:05:05.479940.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-26 12:05:05.479940.txt'
# local_FedAtt = 'results_FedAtt_2025-02-26 13:25:19.867217.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-26 13:25:19.867217.txt'
# local_FedProx = 'results_FedProx_2025-02-26 13:25:13.689653.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-26 13:25:13.689653.txt'
# local_FedAvg = 'results_FedAvg_2025-02-26 13:29:55.229671.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-26 13:29:55.229671.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-26 13:29:34.958705.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-26 13:29:34.958705.txt'

# with different thresholds
# local_FedCluLearn_070 = 'results_FedCluLearn_2025-03-04 10:42:21.373624.txt'
# global_FedCluLearn_070 = 'global_model_evaluation_FedCluLearn_2025-03-04 10:42:21.373624.txt'
# local_FedCluLearn_080 = 'results_FedCluLearn_2025-03-04 10:43:06.616600.txt'
# global_FedCluLearn_080 = 'global_model_evaluation_FedCluLearn_2025-03-04 10:43:06.616600.txt'
# local_FedCluLearn_090 = 'results_FedCluLearn_2025-03-04 11:28:42.427780.txt'
# global_FedCluLearn_090 = 'global_model_evaluation_FedCluLearn_2025-03-04 11:28:42.427780.txt'
# local_FedCluLearn_Prox_070 = 'results_FedCluLearn_Prox_2025-03-04 11:29:08.539834.txt'
# global_FedCluLearn_Prox_070 = 'global_model_evaluation_FedCluLearn_Prox_2025-03-04 11:29:08.539834.txt'
# local_FedCluLearn_Prox_080 = 'results_FedCluLearn_Prox_2025-03-04 11:30:23.357036.txt'
# global_FedCluLearn_Prox_080 = 'global_model_evaluation_FedCluLearn_Prox_2025-03-04 11:30:23.357036.txt'
# local_FedCluLearn_Prox_090 = 'results_FedCluLearn_Prox_2025-03-04 11:30:29.815623.txt'
# global_FedCluLearn_Prox_090 = 'global_model_evaluation_FedCluLearn_Prox_2025-03-04 11:30:29.815623.txt'


# # # experiment 4, local epochs 3 hybrid concept drift
# local_FedAvg = 'results_FedAvg_2025-02-07 12:00:47.595969.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-07 12:00:47.595969.txt'
# local_FedCluLearn = 'results_FedCluLearn_2025-02-07 12:00:32.338353.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-07 12:00:32.338353.txt'
# local_FedAtt = 'results_FedAtt_2025-02-15 16:34:45.104528.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-15 16:34:45.104528.txt'
# local_FedProx = 'results_FedProx_2025-02-16 09:25:39.935276.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-16 09:25:39.935276.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-26 12:14:12.062021.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-26 12:14:12.062021.txt'


# # # experiment 1, recent knowledge, local epochs 3, local concept drift
# local_FedCluLearn = 'results_FedCluLearn_2025-02-07 13:40:27.170073.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-07 13:40:27.170073.txt'
# local_FedAvg = 'results_FedAvg_2025-02-05 11:02:59.570648.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-05 11:02:59.570648.txt'

# local_FedAtt = 'results_FedAtt_2025-02-15 14:24:24.188745.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-15 14:24:24.188745.txt'
# local_FedProx = 'results_FedProx_2025-02-16 08:55:52.957901.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-16 08:55:52.957901.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-26 12:07:09.049414.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-26 12:07:09.049414.txt'

# # # experiment 2, recent knowledge, local epochs 3, global concept drift
# local_FedAvg = 'results_FedAvg_2025-02-07 11:41:15.393233.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-07 11:41:15.393233.txt'
# local_FedCluLearn = 'results_FedCluLearn_2025-02-07 14:56:36.516849.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-07 14:56:36.516849.txt'
# local_FedAtt = 'results_FedAtt_2025-02-15 15:07:47.939783.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-15 15:07:47.939783.txt'
# local_FedProx = 'results_FedProx_2025-02-16 09:21:22.183043.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-16 09:21:22.183043.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-25 20:52:51.925733.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-25 20:52:51.925733.txt'

# new global schema
# local_FedAtt = 'results_FedAtt_2025-02-26 13:25:19.867217.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-26 13:25:19.867217.txt'
# local_FedProx = 'results_FedProx_2025-02-26 13:25:13.689653.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-26 13:25:13.689653.txt'
# local_FedAvg = 'results_FedAvg_2025-02-26 13:29:55.229671.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-26 13:29:55.229671.txt'
# local_FedCluLearn = 'results_FedCluLearn_2025-02-26 13:46:34.610555.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-26 13:46:34.610555.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-26 13:47:10.790761.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-26 13:47:10.790761.txt'

# # # experiment 4, recent knowledge, local epochs 3, hybrid concept drift
# local_FedAvg = 'results_FedAvg_2025-02-07 12:00:47.595969.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-07 12:00:47.595969.txt'
# local_FedCluLearn = 'results_FedCluLearn_2025-02-07 15:14:25.180267.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-07 15:14:25.180267.txt'

# local_FedAtt = 'results_FedAtt_2025-02-15 16:34:45.104528.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-15 16:34:45.104528.txt'
# local_FedProx = 'results_FedProx_2025-02-16 09:25:39.935276.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-16 09:25:39.935276.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-26 12:13:55.152525.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-26 12:13:55.152525.txt'

# # # experiment 1, percentage, local epochs 3, local concept drift
# local_FedAvg = 'results_FedAvg_2025-02-05 11:02:59.570648.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-05 11:02:59.570648.txt'
# local_FedCluLearn = 'results_FedCluLearn_2025-02-07 16:25:15.308613.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-07 16:25:15.308613.txt'
# local_FedAtt = 'results_FedAtt_2025-02-15 14:24:24.188745.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-15 14:24:24.188745.txt'
# local_FedProx = 'results_FedProx_2025-02-16 08:55:52.957901.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-16 08:55:52.957901.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-26 12:07:39.756286.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-26 12:07:39.756286.txt'

# # # experiment 2, percentage, local epochs 3, global concept drift
# local_FedAvg = 'results_FedAvg_2025-02-07 11:41:15.393233.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-07 11:41:15.393233.txt'
# local_FedCluLearn = 'results_FedCluLearn_2025-02-07 16:47:44.265241.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-07 16:47:44.265241.txt'

# local_FedAtt = 'results_FedAtt_2025-02-15 15:07:47.939783.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-15 15:07:47.939783.txt'
# local_FedProx = 'results_FedProx_2025-02-16 09:21:22.183043.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-16 09:21:22.183043.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-25 20:52:31.516371.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-25 20:52:31.516371.txt'


# new schema
# local_FedAtt = 'results_FedAtt_2025-02-26 13:25:19.867217.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-26 13:25:19.867217.txt'
# local_FedProx = 'results_FedProx_2025-02-26 13:25:13.689653.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-26 13:25:13.689653.txt'
# local_FedAvg = 'results_FedAvg_2025-02-26 13:29:55.229671.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-26 13:29:55.229671.txt'
# local_FedCluLearn = 'results_FedCluLearn_2025-02-26 13:25:33.132058.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-26 13:25:33.132058.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-26 13:26:04.885053.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-26 13:26:04.885053.txt'

# # # experiment 4, percentage, local epochs 3, hybrid concept drift
# local_FedAvg = 'results_FedAvg_2025-02-07 12:00:47.595969.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-07 12:00:47.595969.txt'
# local_FedCluLearn = 'results_FedCluLearn_2025-02-07 17:00:37.965425.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-07 17:00:37.965425.txt'

# local_FedAtt = 'results_FedAtt_2025-02-15 16:34:45.104528.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-15 16:34:45.104528.txt'
# local_FedProx = 'results_FedProx_2025-02-16 09:25:39.935276.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-16 09:25:39.935276.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-26 12:14:12.062021.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-26 12:14:12.062021.txt'

# %% [markdown]
# Real experiment results

# %%
# local_FedCluLearn = 'results_FedCluLearn_2025-02-25 09:52:06.632308.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-25 09:52:06.632308.txt'

# local_FedCluLearn = 'results_FedCluLearn_2025-02-25 10:46:05.736246.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-02-25 10:46:05.736246.txt'

# local_FedAvg = 'results_FedAvg_2025-02-25 10:41:23.649440.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-02-25 10:41:23.649440.txt'

# local_FedAtt = 'results_FedAtt_2025-02-25 10:46:18.152654.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-02-25 10:46:18.152654.txt'

# local_FedProx = 'results_FedProx_2025-02-25 10:46:26.787383.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-02-25 10:46:26.787383.txt'

# local_FedCluLearn_recent = 'results_FedCluLearn_2025-02-25 10:54:24.530009.txt'
# global_FedCluLearn_recent = 'global_model_evaluation_FedCluLearn_2025-02-25 10:54:24.530009.txt'

# local_FedCluLearn_Prox_recent = 'results_FedCluLearn_Prox_2025-02-25 10:59:22.761987.txt'
# global_FedCluLearn_Prox_recent = 'global_model_evaluation_FedCluLearn_Prox_2025-02-25 10:59:22.761987.txt'

# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-02-25 10:59:52.753193.txt'
# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-02-25 10:59:52.753193.txt'

# local_FedCluLearn_percentage = 'results_FedCluLearn_2025-02-25 11:11:35.154727.txt'
# global_FedCluLearn_percentage = 'global_model_evaluation_FedCluLearn_2025-02-25 11:11:35.154727.txt'

# local_FedCluLearn_Prox_percentage = 'results_FedCluLearn_Prox_2025-02-25 11:11:59.005370.txt'
# global_FedCluLearn_Prox_percentage = 'global_model_evaluation_FedCluLearn_Prox_2025-02-25 11:11:59.005370.txt'

# local_FedCluLearn_percentage_25 = 'results_FedCluLearn_percentage_2025-03-03 15:00:50.321053.txt'
# global_FedCluLearn_percentage_25 = 'global_model_evaluation_FedCluLearn_percentage_2025-03-03 15:00:50.321053.txt'

# local_FedCluLearn_Prox_percentage_25 = 'results_FedCluLearn_Prox_percentage_2025-03-03 15:01:00.960897.txt'
# global_FedCluLearn_Prox_percentage_25 = 'global_model_evaluation_FedCluLearn_Prox_percentage_2025-03-03 15:01:00.960897.txt'

# local_FedCluLearn_percentage_75 = 'results_FedCluLearn_percentage_2025-03-03 15:01:21.724734.txt'
# global_FedCluLearn_percentage_75 = 'global_model_evaluation_FedCluLearn_percentage_2025-03-03 15:01:21.724734.txt'

# local_FedCluLearn_Prox_percentage_75 = 'results_FedCluLearn_Prox_percentage_2025-03-03 15:01:32.557997.txt'
# global_FedCluLearn_Prox_percentage_75 = 'global_model_evaluation_FedCluLearn_Prox_percentage_2025-03-03 15:01:32.557997.txt'

# %%
# Air quality, 5 partitions, 250 global rounds
# local_FedCluLearn = 'results_FedCluLearn_2025-03-01 09:51:51.529043.txt'
# global_FedCluLearn = 'global_model_evaluation_FedCluLearn_2025-03-01 09:51:51.529043.txt'

# global_FedCluLearn_Prox = 'global_model_evaluation_FedCluLearn_Prox_2025-03-01 09:52:36.832767.txt'
# local_FedCluLearn_Prox = 'results_FedCluLearn_Prox_2025-03-01 09:52:36.832767.txt'

# local_FedAvg = 'results_FedAvg_2025-03-01 10:04:23.908322.txt'
# global_FedAvg = 'global_model_evaluation_FedAvg_2025-03-01 10:04:23.908322.txt'

# local_FedAtt = 'results_FedAtt_2025-03-01 10:04:31.386712.txt'
# global_FedAtt = 'global_model_evaluation_FedAtt_2025-03-01 10:04:31.386712.txt'

# local_FedProx = 'results_FedProx_2025-03-01 10:21:02.496987.txt'
# global_FedProx = 'global_model_evaluation_FedProx_2025-03-01 10:21:02.496987.txt'

# local_FedCluLearn_recent = 'results_FedCluLearn_recent_2025-03-01 10:21:17.925095.txt'
# global_FedCluLearn_recent = 'global_model_evaluation_FedCluLearn_recent_2025-03-01 10:21:17.925095.txt'

# local_FedCluLearn_Prox_recent = 'results_FedCluLearn_Prox_recent_2025-03-01 10:37:43.355040.txt'
# global_FedCluLearn_Prox_recent = 'global_model_evaluation_FedCluLearn_Prox_recent_2025-03-01 10:37:43.355040.txt'

# local_FedCluLearn_Prox_percentage = 'results_FedCluLearn_Prox_percentage_2025-03-01 10:37:51.469483.txt'
# global_FedCluLearn_Prox_percentage = 'global_model_evaluation_FedCluLearn_Prox_percentage_2025-03-01 10:37:51.469483.txt'

# local_FedCluLearn_percentage = 'results_FedCluLearn_percentage_2025-03-01 10:50:36.016247.txt'
# global_FedCluLearn_percentage = 'global_model_evaluation_FedCluLearn_percentage_2025-03-01 10:50:36.016247.txt'

# local_FedCluLearn_percentage_25 = 'results_FedCluLearn_percentage_2025-03-01 18:38:33.162443.txt'
# global_FedCluLearn_percentage_25 = 'global_model_evaluation_FedCluLearn_percentage_2025-03-01 18:38:33.162443.txt'

# local_FedCluLearn_Prox_percentage_25 = 'results_FedCluLearn_Prox_percentage_2025-03-01 18:38:40.197468.txt'
# global_FedCluLearn_Prox_percentage_25 = 'global_model_evaluation_FedCluLearn_Prox_percentage_2025-03-01 18:38:40.197468.txt'

# local_FedCluLearn_Prox_percentage_75 = 'results_FedCluLearn_Prox_percentage_2025-03-01 18:50:18.689538.txt'
# global_FedCluLearn_Prox_percentage_75 = 'global_model_evaluation_FedCluLearn_Prox_percentage_2025-03-01 18:50:18.689538.txt'

# local_FedCluLearn_percentage_75 = 'results_FedCluLearn_percentage_2025-03-01 18:50:24.475484.txt'
# global_FedCluLearn_percentage_75 = 'global_model_evaluation_FedCluLearn_percentage_2025-03-01 18:50:24.475484.txt'

# %% [markdown]
# Control experiments

# %%
local_filenames = [local_FedCluLearn, local_FedAvg, local_FedAtt, local_FedProx, local_FedCluLearn_Prox]
global_filenames = [global_FedCluLearn, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox]

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[local_FedCluLearn, local_FedCluLearn_recent, local_FedCluLearn_percentage, local_FedAvg, local_FedAtt, local_FedProx, local_FedCluLearn_Prox, local_FedCluLearn_Prox_recent, None], mse_column=mse_column)
n_rounds, y = preprocessing_results(filenames=local_filenames, mse_column=mse_column)
plot_plotly(n_rounds, y, title='Avg MSE Local models', y_axis_title=f'{mse_column.upper()} error', y_axis_max=0.3)

# %%
for client_id in [0,1,2]:
    n_rounds, y = preprocessing_results(filenames=local_filenames, client_id=client_id, mse_column='mse')
    plot_plotly(n_rounds, y, title=f'MSE Local model Client {client_id}', y_axis_title='MSE error')

# %%
n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list = preprocessing_results_all_clients2(filename1=local_FedCluLearn, filename2=local_FedCluLearn, filename3=local_FedAtt, filename4=local_FedProx, n_clients=3, mse_column='mse')
plot_plotly3(n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list, n_clients = 3, model='FedCluLearn', title='Local Mean Squared Error over FL Rounds', y_axis_title='Mean Squared Error')

# %%
n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list = preprocessing_results_all_clients2(filename1=local_FedCluLearn, filename2=local_FedAvg, filename3=local_FedAtt, filename4=local_FedProx, n_clients=3, mse_column='mse')
plot_plotly3(n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list, n_clients = 3, model='FedAvg', title='Local Mean Squared Error over FL Rounds', y_axis_title='Mean Squared Error', y_axis_max=1000000000000000)

# %%
mse_column = 'r2'
# n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
# global_filenames = [global_FedCluLearn, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox]
global_filenames = [global_FedCluLearn, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox]
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
#Avg {mse_column.upper()} Global model
plot_plotly(n_rounds, y, title=f'', y_axis_title=f'{mse_column.upper()}', y_axis_max=1, name='I3_r2_percentage')

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
# global_filenames = [global_FedCluLearn, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox]
global_filenames = [global_FedCluLearn, global_FedCluLearn_070, global_FedCluLearn_080, global_FedCluLearn_090]
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
#Avg {mse_column.upper()} Global model
plot_plotly(n_rounds, y, title=f'', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1, algo_name1 = '0.5', algo_name4='0.7', algo_name5='0.8', algo_name6='0.9', name='control_mse_fedclulearn_threshold')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 mse_column = 'mse'
#       2 # n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
#       3 # global_filenames = [global_FedCluLearn, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox]
# ----> 4 global_filenames = [global_FedCluLearn, global_FedCluLearn_070, global_FedCluLearn_080, global_FedCluLearn_090]
#       5 n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
#       6 #Avg {mse_column.upper()} Global model
#
# NameError: name 'global_FedCluLearn' is not defined

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
# global_filenames = [global_FedCluLearn, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox]
global_filenames = [global_FedCluLearn_Prox, global_FedCluLearn_Prox_070, global_FedCluLearn_Prox_080, global_FedCluLearn_Prox_090]
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
#Avg {mse_column.upper()} Global model
plot_plotly(n_rounds, y, title=f'', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1, algo_name1 = '0.5', algo_name4='0.7', algo_name5='0.8', algo_name6='0.9', name='control_mse_fedclulearn_prox_threshold')

# %%
mse_column='mse'
for client_id in [0,1,2]:
    n_rounds, y = preprocessing_results(filenames=global_filenames, client_id=client_id,mse_column=mse_column)
    plot_plotly(n_rounds, y, title=f'Global model - test data Client {client_id}', y_axis_title=f'{mse_column} error')

# %%
mse_column='mse'
for client_id in [0,1,2]:
    n_rounds, y = preprocessing_results(filenames=[local_FedCluLearn, global_FedCluLearn, None, None, None], client_id=client_id,mse_column=mse_column)
    plot_plotly(n_rounds, y, title=f'Local vs Global Client {client_id}', y_axis_title=f'{mse_column} error', algo_name1='Local FedCluLearn', algo_name4='Global FedCluLearn')

# %% [markdown]
# # Real experiment

# %%
local_filenames = [local_FedCluLearn, local_FedCluLearn_recent, local_FedCluLearn_percentage, local_FedAvg, local_FedAtt, local_FedProx, local_FedCluLearn_Prox, local_FedCluLearn_Prox_recent, local_FedCluLearn_Prox_percentage, local_FedCluLearn_percentage_25, local_FedCluLearn_percentage_75, local_FedCluLearn_Prox_percentage_25, local_FedCluLearn_Prox_percentage_75]
global_filenames = [global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, global_FedCluLearn_Prox_percentage, global_FedCluLearn_percentage_25, global_FedCluLearn_percentage_75, global_FedCluLearn_Prox_percentage_25, global_FedCluLearn_Prox_percentage_75]

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[local_FedCluLearn, local_FedCluLearn_recent, local_FedCluLearn_percentage, local_FedAvg, local_FedAtt, local_FedProx, local_FedCluLearn_Prox, local_FedCluLearn_Prox_recent, None], mse_column=mse_column)
n_rounds, y = preprocessing_results(filenames=local_filenames, mse_column=mse_column)
plot_plotly_real(n_rounds, y, title='Avg MSE Local models', y_axis_title=f'{mse_column.upper()} error', y_axis_max=0.3)

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
global_filenames = [global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, global_FedCluLearn_Prox_percentage, global_FedCluLearn_percentage_25, global_FedCluLearn_percentage_75, global_FedCluLearn_Prox_percentage_25, global_FedCluLearn_Prox_percentage_75]
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
plot_plotly_real(n_rounds, y, title=f'Avg {mse_column.upper()} Global model', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1)

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
global_filenames = [global_FedCluLearn, None, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, None, global_FedCluLearn_Prox_percentage, global_FedCluLearn_percentage_25, global_FedCluLearn_percentage_75, global_FedCluLearn_Prox_percentage_25, global_FedCluLearn_Prox_percentage_75]
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
plot_plotly_real(n_rounds, y, title=f'', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1)  #Avg {mse_column.upper()} Global model

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
# global_filenames = [None, None, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, None, None, global_FedCluLearn_Prox_percentage, None, None, None, None]
global_filenames = [None, None, None, global_FedAvg, global_FedAtt, global_FedProx, None, None, None, global_FedCluLearn_percentage_25, None, global_FedCluLearn_Prox_percentage_25, None]
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
plot_plotly_real(n_rounds, y, title=f'', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1, name='real_mse_air_all_5_parts')  #Avg {mse_column.upper()} Global model

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
global_filenames = [global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, None, None, None, None, None, None, global_FedCluLearn_percentage_25, global_FedCluLearn_percentage_75, None, None]
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
plot_plotly_real(n_rounds, y, title=f'', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1, name='real_mse_air_fedclulearn_5_parts')  # Avg {mse_column.upper()} Global model

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
global_filenames = [None, None, None, None, None, None, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, global_FedCluLearn_Prox_percentage, None, None, global_FedCluLearn_Prox_percentage_25, global_FedCluLearn_Prox_percentage_75]
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
plot_plotly_real(n_rounds, y, title=f'', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1, name='real_mse_air_fedclulearn_prox_5_parts')  # Avg {mse_column.upper()} Global model

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
global_filenames = [global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, global_FedCluLearn_Prox_percentage, None, None, global_FedCluLearn_Prox_percentage_25, global_FedCluLearn_Prox_percentage_75]
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
plot_plotly_real(n_rounds, y, title=f'Avg {mse_column.upper()} Global model', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1)

# %%
mse_column = 'mse'
# n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, None], mse_column=mse_column)
global_filenames = [global_FedCluLearn, global_FedCluLearn_recent, global_FedCluLearn_percentage, None, None, None, global_FedCluLearn_Prox, global_FedCluLearn_Prox_recent, global_FedCluLearn_Prox_percentage]
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
plot_plotly(n_rounds, y, title=f'Avg {mse_column.upper()} Global model', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1)

# %%
mse_column = 'mse'
n_rounds, y = preprocessing_results(filenames=[global_FedCluLearn, None, None, global_FedAvg, global_FedAtt, global_FedProx, None, None, None], mse_column=mse_column)
plot_plotly(n_rounds, y, title=f'', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1)

# %%
mse_column = 'mse'
n_rounds, y = preprocessing_results(filenames=[None, None, None, global_FedAvg, global_FedAtt, global_FedProx, global_FedCluLearn_Prox, None, None], mse_column=mse_column)
plot_plotly(n_rounds, y, title=f'', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1)

# %%
mse_column = 'mse'
n_rounds, y = preprocessing_results(filenames=global_filenames, mse_column=mse_column)
plot_plotly(n_rounds, y, title=f'Avg {mse_column.upper()} Global model', y_axis_title=f'{mse_column.upper()} error', y_axis_max=1)

# %%
mse_column='mse'
for client_id in [0,1,2]:
    n_rounds, y = preprocessing_results(filenames=global_filenames, client_id=client_id,mse_column=mse_column)
    plot_plotly(n_rounds, y, title=f'Global model - test data Client {client_id}', y_axis_title=f'{mse_column} error')

# %%
mse_column='mse'
for client_id in [0,1,2]:
    n_rounds, y = preprocessing_results(filenames=[local_FedCluLearn, None, None, global_FedCluLearn, None, None, None, None, None], client_id=client_id,mse_column=mse_column)
    plot_plotly(n_rounds, y, title=f'Local vs Global Client {client_id}', y_axis_title=f'{mse_column} error', algo_name1='Local FedCluLearn', algo_name2='Global FedCluLearn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[460], line 4
#       2 for client_id in [0,1,2]:
#       3     n_rounds, y = preprocessing_results(filenames=[local_FedCluLearn, None, None, global_FedCluLearn, None, None, None, None, None], client_id=client_id,mse_column=mse_column)
# ----> 4     plot_plotly(n_rounds, y, title=f'Local vs Global Client {client_id}', y_axis_title=f'{mse_column} error', algo_name1='Local FedCluLearn', algo_name2='Global FedCluLearn')
#
# TypeError: plot_plotly() got an unexpected keyword argument 'algo_name2'

# %%
n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list = preprocessing_results_all_clients2(filename1=global_FedCluLearn, filename2=None, filename3=None, filename4=None, n_clients=3, mse_column='mse')
plot_plotly3(n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list, n_clients = 3, model='FedCluLearn', title='Global Mean Squared Error over FL Rounds', y_axis_title='Mean Squared Error', y_axis_max=50)

# %%
n_rounds, y_df_list, y_df1_list, y_df2_list , y_df3_list = preprocessing_results_all_clients2(filename1=None, filename2=global_FedAvg, filename3=None, filename4=None, n_clients=3, mse_column='mse')
plot_plotly3(n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list, n_clients = 3, model='FedAvg', title='Global Mean Squared Error over FL Rounds', y_axis_title='Mean Squared Error', y_axis_max=150)

# %%
n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list = preprocessing_results_all_clients2(filename1=None, filename2=None, filename3=global_FedAtt, filename4=None, n_clients=3, mse_column='mse')
plot_plotly3(n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list, n_clients = 3, model='FedAtt', title='Global Mean Squared Error over FL Rounds', y_axis_title='Mean Squared Error', y_axis_max=150)

# %%
n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list = preprocessing_results_all_clients2(filename1=None, filename2=None, filename3=None, filename4=global_FedProx, n_clients=3, mse_column='mse')
plot_plotly3(n_rounds, y_df_list, y_df1_list, y_df2_list, y_df3_list, n_clients = 3, model='FedProx', title='Global Mean Squared Error over FL Rounds', y_axis_title='Mean Squared Error', y_axis_max=150)
